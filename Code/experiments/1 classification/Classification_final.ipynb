# %% [markdown]
# # Optimization

# %% [markdown]
# ### Collect training features

# %%
import numpy as np
import random
import os, sys
import matplotlib.pyplot as plt
import warnings
from lib.esn import ESN
from dataset.loading import Feature_Collector

random.seed(0)
np.random.seed(0)
warnings.filterwarnings("ignore")

directory = os.path.abspath('/Users/joris/Documents/Work/bsc ai/bt/Bachelor-Thesis/code')
sys.path.append(directory)

path = '../../data/'
fc = Feature_Collector(path)

dr = []
speakers = []
XorZ = "Z"
long_version = False
n_mels = 13
delta = False
delta_delta = False
subsamples = 10
const_params = {
    "n_mels":n_mels,
    "XorZ":XorZ
}

path_option = "Final"+str(long_version)+str(n_mels)+str(delta)+str(delta_delta)+str(subsamples)

if dr:
    path_option = str(dr)+"_"+path_option
if len(speakers):
    path_option = str(speakers[0])+"_"+path_option

features_train, labels_train, _ = fc.collectFeaturesInSegments(
    n_mels=n_mels, delta=delta, delta_delta=delta_delta,
    long_version=long_version, speakers=speakers, dr=dr,
    subsamples=subsamples, path_option=path_option)
# Out:
# -from output
# ---- success

# %% [markdown]
# ### Regroup data and subset phonemes

# %%
from dataset.data_helpers import *

phonemes, features_train, labels_train = filter_data(features_train, labels_train, limit=None)
# Out:
# Filtered to 177080 samples of shape (10, 13)

# %% [markdown]
# ### Compute conceptors

# %%
from lib.experiment_helpers import *
from sklearn.base import BaseEstimator, ClassifierMixin

class Classifier(BaseEstimator, ClassifierMixin):

    def __init__(self,
                 W_in_scale,
                 b_scale,
                 spectral_radius,
                 weights):
        self.W_in_scale = W_in_scale
        self.spectral_radius = spectral_radius
        self.b_scale = b_scale
        self.weights = weights

    def fit(self, X, y, **params):
        self.n_mels = params["n_mels"]
        self.XorZ = params["XorZ"]

        # Group data by class
        group = group_by_labels(X, y)

        self.classes = list(group.keys())
        self.n_samples = sum([len(x) for x in list(group.values())])

        print(f"Number of samples: {self.n_samples}")
        # Init Reservoir
        esn_params = {
            "in_dim": self.n_mels,
            "out_dim": self.n_mels,
            "N": 4 + 6 * (self.XorZ == "X"),
            "W_in_scale": self.W_in_scale,
            "b_scale": self.b_scale,
            "spectral_radius": self.spectral_radius,
            "weights": self.weights
        }
        self.esn = ESN(esn_params)
        self.Cs_clas, self.Ns_clas = compute_Cs_and_Ns(group, esn=self.esn, aperture="auto", normalize=True, XorZ=self.XorZ, cache=False)

        # Return the classifier
        return self

    def predict(self, X):
        y = []
        for sample in X:
            x = self.esn.run(sample.T, XorZ=self.XorZ)
            es = evidences_for_Cs(x,self.Cs_clas,self.Ns_clas)
            if self.XorZ == "X":
                es = [ np.sum(p) for p in es ]
            y.append(self.classes[np.argmax(es)])

        return y

# %%
from sklearn.model_selection import train_test_split
from bayes_opt import BayesianOptimization

X_train, X_test, y_train, y_test = train_test_split(features_train, labels_train,
                                        stratify = labels_train,
                                        random_state = 1)


# Bayesian Optimization wrapper
def objective_function(W_in_scale,
                       b_scale,
                       spectral_radius,
                       weights):
    model = Classifier(W_in_scale,
                 b_scale,
                 spectral_radius,
                 weights)
    model.fit(X_train, y_train, **const_params)
    return model.score(X_test, y_test)


parameters = {
    'W_in_scale': [.01, 2],
    'spectral_radius': [0.01, 4],
    'b_scale': [0, 2],
    'weights': [.01,1]
}

# Bayesian optimization of the objective function.
optimizer = BayesianOptimization(f = objective_function,
                                 pbounds = parameters,
                                 random_state = 1)
optimizer.maximize(init_points = 10, n_iter = 50)

best_params = optimizer.max['params']
print(f"Best parmaters: {best_params}; f(x) = {optimizer.max['target']}.")
# Out:
# |   iter    |  target   | W_in_s... |  b_scale  | spectr... |  weights  |
# -------------------------------------------------------------------------
# Number of samples: 292
# - computing conceptors
# optimizing
# Computing gammas...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/envs/Bachelor-Thesis/lib/python3.10/site-packages/bayes_opt/target_space.py:191, in TargetSpace.probe(self, params)
#     190 try:
# --> 191     target = self._cache[_hashable(x)]
#     192 except KeyError:
#
# KeyError: (0.8398737893581223, 1.4406489868843162, 0.010456355521206098, 0.30930924690552136)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 33>()
#      29 # Bayesian optimization of the objective function.
#      30 optimizer = BayesianOptimization(f = objective_function,
#      31                                  pbounds = parameters,
#      32                                  random_state = 1)
# ---> 33 optimizer.maximize(init_points = 10, n_iter = 50)
#      35 best_params = optimizer.max['params']
#      36 print(f"Best parmaters: {best_params}; f(x) = {optimizer.max['target']}.")
#
# File ~/opt/miniconda3/envs/Bachelor-Thesis/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:305, in BayesianOptimization.maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     303     x_probe = self.suggest(util)
#     304     iteration += 1
# --> 305 self.probe(x_probe, lazy=False)
#     307 if self._bounds_transformer and iteration > 0:
#     308     # The bounds transformer should only modify the bounds after
#     309     # the init_points points (only for the true iterations)
#     310     self.set_bounds(
#     311         self._bounds_transformer.transform(self._space))
#
# File ~/opt/miniconda3/envs/Bachelor-Thesis/lib/python3.10/site-packages/bayes_opt/bayesian_optimization.py:200, in BayesianOptimization.probe(self, params, lazy)
#     198     self._queue.add(params)
#     199 else:
# --> 200     self._space.probe(params)
#     201     self.dispatch(Events.OPTIMIZATION_STEP)
#
# File ~/opt/miniconda3/envs/Bachelor-Thesis/lib/python3.10/site-packages/bayes_opt/target_space.py:194, in TargetSpace.probe(self, params)
#     192 except KeyError:
#     193     params = dict(zip(self._keys, x))
# --> 194     target = self.target_func(**params)
#     195     self.register(x, target)
#     196 return target
#
# Input In [4], in objective_function(W_in_scale, b_scale, spectral_radius, weights)
#      10 def objective_function(W_in_scale,
#      11                        b_scale,
#      12                        spectral_radius,
#      13                        weights):
#      14     model = Classifier(W_in_scale,
#      15                  b_scale,
#      16                  spectral_radius,
#      17                  weights)
# ---> 18     model.fit(X_train, y_train, **const_params)
#      19     return model.score(X_test, y_test)
#
# Input In [3], in Classifier.fit(self, X, y, **params)
#      28 esn_params = {
#      29     "in_dim": self.n_mels,
#      30     "out_dim": self.n_mels,
#    (...)
#      35     "weights": self.weights
#      36 }
#      37 self.esn = ESN(esn_params)
# ---> 38 self.Cs_clas, self.Ns_clas = compute_Cs_and_Ns(group, esn=self.esn, aperture="auto", normalize=True, XorZ=self.XorZ, cache=False)
#      40 # Return the classifier
#      41 return self
#
# File ~/Documents/Work/bsc ai/bt/Bachelor-Thesis/code/lib/experiment_helpers.py:14, in compute_Cs_and_Ns(group, esn, aperture, normalize, XorZ, cache)
#      13 def compute_Cs_and_Ns(group, esn, aperture="auto", normalize=True, XorZ="X", cache=True):
# ---> 14     Cs = compute_Cs(group, esn, aperture, normalize, XorZ, cache)
#      15     print("- computing negative conceptors")
#      16     Ns = Ns_from_Cs(Cs)
#
# File ~/Documents/Work/bsc ai/bt/Bachelor-Thesis/code/lib/experiment_helpers.py:62, in compute_Cs(group, esn, aperture, normalize, XorZ, cache)
#      60 if aperture == "auto":
#      61     print("optimizing")
# ---> 62     Cs = optimize_apertures(Cs, start=0.5, end=500, n=150)
#      63     for l, C in zip(sum_hist, Cs):
#      64         l.append(sum_of_singular_vals(C))
#
# File ~/Documents/Work/bsc ai/bt/Bachelor-Thesis/code/lib/conceptors.py:153, in optimize_apertures(Cs, start, end, n)
#     150 print("Computing gammas...")
#     151 for i, C in enumerate(Cs):
#     152     #print(i + 1, " of ", len(Cs))
# --> 153     gammas.append(best_gamma(C, start, end, n))
#     154 optimal_gamma = np.mean(gammas)
#     155 print("Optimal gamma: ", optimal_gamma)
#
# File ~/Documents/Work/bsc ai/bt/Bachelor-Thesis/code/lib/conceptors.py:184, in best_gamma(C, start, end, n)
#     182 for i in range(len(gammas) - 1):
#     183     dgamma = gammas[i + 1] - gammas[i]
# --> 184     df = phi_squared(gamma=gammas[i + 1], C=C) - phi_squared(gamma=gammas[i], C=C)
#     185     ds.append(gammas[i] * df / dgamma)
#     186 return gammas[np.argmax(ds)]
#
# File ~/Documents/Work/bsc ai/bt/Bachelor-Thesis/code/lib/conceptors.py:173, in phi_squared(gamma, C)
#     172 def phi_squared(gamma, C):
# --> 173     return linalg.norm(phi(C, R=None, gamma=gamma), 'fro') ** 2
#
# File ~/Documents/Work/bsc ai/bt/Bachelor-Thesis/code/lib/conceptors.py:165, in phi(C, gamma, R)
#     163     gamma = gamma[0]
#     164 if C is not None:
# --> 165     return C @ inv(C + gamma ** (-2) * (np.eye(C.shape[0]) - C))
#     166 elif R is not None:
#     167     Eig_vals, _ = np.linalg.eig(R)
#
# File ~/opt/miniconda3/envs/Bachelor-Thesis/lib/python3.10/site-packages/scipy/linalg/basic.py:966, in inv(a, overwrite_a, check_finite)
#     959     # XXX: the following line fixes curious SEGFAULT when
#     960     # benchmarking 500x500 matrix inverse. This seems to
#     961     # be a bug in LAPACK ?getri routine because if lwork is
#     962     # minimal (when using lwork[0] instead of lwork[1]) then
#     963     # all tests pass. Further investigation is required if
#     964     # more such SEGFAULTs occur.
#     965     lwork = int(1.01 * lwork)
# --> 966     inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     967 if info > 0:
#     968     raise LinAlgError("singular matrix")
#
# KeyboardInterrupt:

# %% [markdown]
# # Plotting Progress

# %%
plt.rcParams['text.usetex'] = True
plt.figure(figsize = (15, 5))

# Scores:
plt.plot(range(1, 1 + len(optimizer.space.target)), optimizer.space.target, label="Accuracy - $f(\\rho$, $k_{W^in}$, $k_b$, $r$)")

# Parameters
W_in_scale = []
b_scale = []
spectral_radius = []
weights = []

for res in optimizer.res:
    W_in_scale.append(res["params"]["W_in_scale"])
    b_scale.append(res["params"]["b_scale"])
    spectral_radius.append(res["params"]["spectral_radius"])
    weights.append(res["params"]["weights"])

if False:
    plt.plot(range(1, 1 + len(optimizer.space.target)), W_in_scale, "--", label="$W^in$")
    plt.plot(range(1, 1 + len(optimizer.space.target)), b_scale, "--", label="$k_b$")
    plt.plot(range(1, 1 + len(optimizer.space.target)), spectral_radius, "--", label="$r$")
    plt.plot(range(1, 1 + len(optimizer.space.target)), weights, "--", label="$\\rho$")

plt.grid(True)
plt.xlabel("Iteration", fontsize = 20)
plt.legend(loc="upper left", fontsize = 20)
plt.show()

# %% [markdown]
# ## Classification

# %%
# Method "X"
optx = Classifier(1.5,
    .2,
    1.5,
    .1)

optx.fit(features_train, labels_train, **{
    "n_mels":n_mels,
    "XorZ":'X'
})

# # Method "Z
# optz = Classifier(1.5,
#     .2,
#     1.5,
#     .1)
#
# optz.fit(features_train, labels_train, **{
#     "n_mels":n_mels,
#     "XorZ":"Z"
# })
# Out:
# Number of samples: 177080
# - computing conceptors
# optimizing
# Computing gammas...
# Optimal gamma:  63.34303831151579
# normalizing
# Target:  7.373755031649612
# std 0.32811292459167296
# - computing negative conceptors
# Classifier(W_in_scale=1.5, b_scale=0.2, spectral_radius=1.5, weights=0.1)

# %% [markdown]
# ## Testing
# ### Feature Collection

# %%
print("Testing...")

features_test, labels_test, _ = fc.collectFeaturesInSegments(
    ft='Test',n_mels=n_mels,delta=delta,delta_delta=delta_delta,
    long_version=long_version,speakers=[],dr=dr,sentence=[],
    subsamples=subsamples,path_option=path_option+"_test")

_, features_test, labels_test = filter_data(features_test, labels_test, limit=None)

print(f'Training Accuracy of x : {optx.score(features_train, labels_train)}')
print(f'Test Accuracy of x     : {optx.score(features_test, labels_test)}')

# print(f'Training Accuracy of z : {optz.score(features_train, labels_train)}')
# print(f'Test Accuracy of z     : {optz.score(features_test, labels_test)}')
# Out:
# Testing...
# -from output
# ---- success
# Filtered to 64145 samples of shape (10, 13)
# Training Accuracy of x : 0.4064151795798509
# Test Accuracy of x     : 0.40419362382103047

# %% [markdown]
# # Displaying Confusion Matrix

# %%
cm = confusion_matrix(labels_test, opt.predict(features_test), labels=phonemes)

# %%
plt.rcParams['text.usetex'] = False

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

from sklearn.metrics import confusion_matrix


# Plot non-normalized confusion matrix
plot_confusion_matrix(cm, target_names=phonemes,
                      title='Confusion matrix, without normalization')

plt.show()

# %%
#with open('res.txt','x') as file:
#    file.write(opt.score(fv,lv))
#    file.write(opt.best_params_)
